# %% [markdown]
# # Lesson 1 Assignment - EnergyLoads
# ## Author - Ryan Arbow

# %% [markdown]
# ### Instructions
# In this exercise you will use visualization and summary statistical methods to explore a data set. You will be looking for interesting aspects in these data. Specifically, you will explore an energy efficiency data set.
#
# This data set contains characteristics of over 750 buildings. The efficiency of the building is measured as either heating load or cooling load. Your goal is to find **three interesting relationships within the variables** which help you understand the energy efficiency of these buildings.
#
# The exercise is deliberately open-ended. Whenever you approach a new data set some open-ended exploration is required. Expect this exploration to be an iterative process. You may need to try several ideas before you find truly interesting relationships.
#
# The key points come from examining charts and summary statistics based on distribution Heating Load and Cooling Load.
# <font color="blue">At the end of this notebook include Markdown cells outlining your 3 key points.</font>
#
# Example description:  The heating load of buildings depends on ... Evidence for this relationship can be seen by ... in the figure and by noting .... in the table above.

# %% [markdown]
# #### Tip:
# There are no categorical variables in this data set. There are two numeric variables, Orientation and Glazing Area Distribution, with only 4 and 2 discrete values. You can convert these integer values to factors and examine the effect on the distribution of Heating Load and Cooling Load.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cleaned up Dataset location
fileName = "https://library.startlearninglabs.uw.edu/DATASCI410/Datasets/EnergyEfficiencyData.csv"

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (768, 10)
# Relative Compactness          float64
# Surface Area                  float64
# Wall Area                     float64
# Roof Area                     float64
# Overall Height                float64
# Orientation                  category
# Glazing Area                  float64
# Glazing Area Distribution    category
# Heating Load                  float64
# Cooling Load                  float64
# dtype: object

# %%
df.describe()
# Out:
#        Relative Compactness  Surface Area   Wall Area   Roof Area  \
# count            768.000000    768.000000  768.000000  768.000000
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        Overall Height  Glazing Area  Heating Load  Cooling Load
# count       768.00000    768.000000    768.000000    768.000000
# mean          5.25000      0.234375     22.307201     24.587760
# std           1.75114      0.133221     10.090196      9.513306
# min           3.50000      0.000000      6.010000     10.900000
# ...

# %%
df.head(10)
# Out:
#    Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
# 5                  0.90         563.5      318.5     122.50             7.0
# 6                  0.90         563.5      318.5     122.50             7.0
# 7                  0.90         563.5      318.5     122.50             7.0
# 8                  0.86         588.0      294.0     147.00             7.0
# 9                  0.86         588.0      294.0     147.00             7.0
#
#    Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# ...

# %%
df.tail()
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 763                  0.64         784.0      343.0      220.5             3.5
# 764                  0.62         808.5      367.5      220.5             3.5
# 765                  0.62         808.5      367.5      220.5             3.5
# 766                  0.62         808.5      367.5      220.5             3.5
# 767                  0.62         808.5      367.5      220.5             3.5
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load  \
# 763            5           0.4                          5         17.88
# 764            2           0.4                          5         16.54
# 765            3           0.4                          5         16.44
# 766            4           0.4                          5         16.48
# 767            5           0.4                          5         16.64
#
#      Cooling Load
# 763         21.40
# 764         16.88
# ...

# %%
# %matplotlib inline

# %%
#get list of columns
print(df.columns)
# Out:
# Index(['Relative Compactness', 'Surface Area', 'Wall Area', 'Roof Area',
#        'Overall Height', 'Orientation', 'Glazing Area',
#        'Glazing Area Distribution', 'Heating Load', 'Cooling Load'],
#       dtype='object')

# %%
#change orientation and glazing area distribution to categorical variables
df['Orientation'] = df['Orientation'].astype('category')
df['Glazing Area Distribution'] = df['Glazing Area Distribution'].astype('category')

# %%
print(df.dtypes)
# Out:
# Relative Compactness          float64
# Surface Area                  float64
# Wall Area                     float64
# Roof Area                     float64
# Overall Height                float64
# Orientation                  category
# Glazing Area                  float64
# Glazing Area Distribution    category
# Heating Load                  float64
# Cooling Load                  float64
# dtype: object

# %%
#histogram of heating load
df.loc[:,'Heating Load'].plot.hist(bins = 30)

# %%
#Kernel density plot of heating load
import seaborn as sns
fig = plt.figure(figsize=(6,6)) # Define plot area
ax = fig.gca() # Define axis 
sns.set_style("whitegrid")
sns.kdeplot(df.loc[:, 'Heating Load'], ax = ax)
ax.set_title('KDE plot of Heating Load') # Give the plot a main title
ax.set_xlabel('Heating Load') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis
# Out:
# Text(0,0.5,'Density')

# %%
#histogram of cooling load
df.loc[:,'Cooling Load'].plot.hist(bins = 30)

# %%
#KDE of heating load
import seaborn as sns
fig = plt.figure(figsize=(6,6)) # Define plot area
ax = fig.gca() # Define axis 
sns.set_style("whitegrid")
sns.kdeplot(df.loc[:, 'Cooling Load'], ax = ax)
ax.set_title('KDE plot of Cooling Load') # Give the plot a main title
ax.set_xlabel('Cooling Load') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis
# Out:
# Text(0,0.5,'Density')

# %%
#histogram of wall area
df.loc[:,'Wall Area'].plot.hist(bins = 10)

# %%
#KDE of wall area
import seaborn as sns
fig = plt.figure(figsize=(6,6)) # Define plot area
ax = fig.gca() # Define axis 
sns.set_style("whitegrid")
sns.kdeplot(df.loc[:, 'Wall Area'], ax = ax)
ax.set_title('KDE plot of Wall Area') # Give the plot a main title
ax.set_xlabel('Wall Area') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis
# Out:
# Text(0,0.5,'Density')

# %%
#KDE of roof area
import seaborn as sns
fig = plt.figure(figsize=(6,6)) # Define plot area
ax = fig.gca() # Define axis 
sns.set_style("whitegrid")
sns.kdeplot(df.loc[:, 'Roof Area'], ax = ax)
ax.set_title('KDE plot of Roof Area') # Give the plot a main title
ax.set_xlabel('Roof Area') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis
# Out:
# Text(0,0.5,'Density')

# %%
#KDE of relative compactness
import seaborn as sns
fig = plt.figure(figsize=(6,6)) # Define plot area
ax = fig.gca() # Define axis 
sns.set_style("whitegrid")
sns.kdeplot(df.loc[:, 'Relative Compactness'], ax = ax)
ax.set_title('KDE plot of Relative Compactness') # Give the plot a main title
ax.set_xlabel('Relative Compactness') # Set text for the x axis
ax.set_ylabel('Density')# Set text for y axis
# Out:
# Text(0,0.5,'Density')

# %%
#Heating Load by Orientation box plot
fig = plt.figure(figsize=(10, 10)) # Define plot area
ax = fig.gca() # Define axis
df.loc[:,['Heating Load', 'Orientation']].boxplot(by = ['Orientation'], ax = ax)
ax.set_title('Box plot of heating load') # Give the plot a main title
ax.set_ylabel('Heating Load')# Set text for y axis
ax.set_ylim(0.0, 50.0) # Set the limits of the y axis
# Out:
# (0.0, 50.0)

# %%
#Cooling load by Orientation box plot
fig = plt.figure(figsize=(10,10)) #Define plot area
ax = fig.gca() #define axis
df.loc[:,['Cooling Load', 'Orientation']].boxplot(by = ['Orientation'], ax = ax)
ax.set_title('Box plot of Cooling Load by Orientation') #set title
ax.set_ylabel('Cooling Load') #set text for y axis
ax.set_ylim(0.0, 50.0) # Set the limits of y axis
# Out:
# (0.0, 50.0)

# %%
#Comparing Heating and Cooling Loads by Orientation box plots 
fig = plt.figure(figsize=(10, 10)) # Define plot area
ax = fig.gca() # Define axis
df.loc[:,['Heating Load', 'Cooling Load', 'Orientation']].boxplot(by = ['Orientation'], ax = ax)
ax.set_title('Box plot of Heating and Cooling Load') # Give the plot a main title
ax.set_ylabel('Heating/Cooling Load')# Set text for y axis
ax.set_ylim(0.0, 50.0) # Set the limits of the y axis
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:2257: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   return_type=return_type, **kwds)
# (0.0, 50.0)

# %%
#Heating Load by Glazing Area Distribution box plot
fig = plt.figure(figsize=(10, 10)) # Define plot area
ax = fig.gca() # Define axis d
df.loc[:,['Heating Load', 'Glazing Area Distribution']].boxplot(by = ['Glazing Area Distribution'], ax = ax)
ax.set_title('Box plot of price') # Give the plot a main title
ax.set_ylabel('Auto Price')# Set text for y axis
ax.set_ylim(0.0, 50.0) # Set the limits of the y axis
# Out:
# (0.0, 50.0)

# %%
#Cooling Load by Glazing Area Distribution box plot
fig = plt.figure(figsize=(10, 10)) # Define plot area
ax = fig.gca() # Define axis d
df.loc[:,['Cooling Load', 'Glazing Area Distribution']].boxplot(by = ['Glazing Area Distribution'], ax = ax)
ax.set_title('Box plot of price') # Give the plot a main title
ax.set_ylabel('Auto Price')# Set text for y axis
ax.set_ylim(0.0, 50.0) # Set the limits of the y axis
# Out:
# (0.0, 50.0)

# %%
#Comparing Heating and Cooling Loads by Glazing Area Distribution box plots 
fig = plt.figure(figsize=(10, 10)) # Define plot area
ax = fig.gca() # Define axis d
df.loc[:,['Heating Load', 'Cooling Load', 'Glazing Area Distribution']].boxplot(by = ['Glazing Area Distribution'], ax = ax)
ax.set_title('Box plot of price') # Give the plot a main title
ax.set_ylabel('Auto Price')# Set text for y axis
ax.set_ylim(0.0, 50.0) # Set the limits of the y axis
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:2257: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   return_type=return_type, **kwds)
# (0.0, 50.0)

# %% [markdown]
# ## Key Points

# %% [markdown]
# 1. There is considerable overlap between the interquartile ranges of the Heating Load distributions by Orientation. This can be seen by the consistent green median line in the Heating Load by Orientation box plot.
#
# 2. The median Cooling Load is higher than the Heating Load across Orientations. This represented by the Boxplot grouped by Orientation plot above showing the median (green) Cooling Load line above 20 across all Orientations as the median (green) Heating Load line below 20 across all Orientations.
#
# 3. There is considerable overlap between the interquartile ranges of Heating and Cooling Loads across the Glazing Area Distributions for values 1-5. This can be seen in the Boxplot grouped by Glazing Area Distribution plot above.
